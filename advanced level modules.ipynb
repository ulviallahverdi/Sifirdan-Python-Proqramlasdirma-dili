# %%
# Datetime modulu

# %%
from datetime import datetime

# %%
dir(datetime)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'astimezone',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'dst',
#  'fold',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'now',
#  'replace',
#  'resolution',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'today',
#  'toordinal',
#  'tzinfo',
#  'tzname',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'weekday',
#  'year']

# %%
indiki_zaman = datetime.now()

# %%
indiki_zaman
# Out:
# datetime.datetime(2021, 12, 22, 20, 21, 25, 578076)

# %%
indiki_zaman.day
# Out:
# 22

# %%
indiki_zaman.month
# Out:
# 12

# %%
indiki_zaman.hour
# Out:
# 20

# %%
indiki_zaman.minute
# Out:
# 21

# %%
indiki_zaman.second
# Out:
# 25

# %%
indiki_zaman.microsecond
# Out:
# 578076

# %%
print(datetime.ctime(indiki_zaman))
# Out:
# Wed Dec 22 20:21:25 2021

# %%
i = datetime.now()

# %%
i
# Out:
# datetime.datetime(2021, 12, 22, 20, 24, 4, 708769)

# %%
print(datetime.strftime(i, "%Y"))
# Out:
# 2021

# %%
print(datetime.strftime(i, "%B"))
# Out:
# December

# %%
print(datetime.strftime(i, "%X"))
# Out:
# 20:24:04

# %%
print(datetime.strftime(i, "%D"))
# Out:
# 12/22/21

# %%
print(datetime.strftime(i, "%X %B %A"))
# Out:
# 20:24:04 December Wednesday

# %%
import locale

# %%
print(locale.setlocale(locale.LC_ALL,""))
# Out:
# English_United States.1252

# %%
# timestamp() ve fromtimestamp()

# %%
i
# Out:
# datetime.datetime(2021, 12, 22, 20, 24, 4, 708769)

# %%
datetime.timestamp(i)
# Out:
# 1640190244.708769

# %%
saniye = datetime.timestamp(i)

# %%
saniye
# Out:
# 1640190244.708769

# %%
zaman = datetime.fromtimestamp(saniye)

# %%
zaman
# Out:
# datetime.datetime(2021, 12, 22, 20, 24, 4, 708769)

# %%
zaman = datetime.fromtimestamp(0)

# %%
zaman
# Out:
# datetime.datetime(1970, 1, 1, 4, 0)

# %%
tarix = datetime(2019,12,1)

# %%
tarix
# Out:
# datetime.datetime(2019, 12, 1, 0, 0)

# %%
i = datetime.now()

# %%
ferq = tarix - i

# %%
ferq
# Out:
# datetime.timedelta(days=-753, seconds=12587, microseconds=735647)

# %%
ferq.days
# Out:
# -753

# %%
ferq.seconds
# Out:
# 12587

# %%
# os modulu

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\uallahverdiyev\\Desktop'

# %%
os.mkdir("GUNEL")

# %%
os.mkdir("AQIL")

# %%
os.mkdir("SANAN")

# %%
os.mkdir("AQIL/SANAN")

# %%
os.mkdir("AQIL/SANAN")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-ed6c6d8bff1b> in <module>
# ----> 1 os.mkdir("AQIL/SANAN")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'AQIL/SANAN'

# %%
os.makedirs("AQIL/SANAN")

# %%
os.rename("SANAN","AQIL")

# %%
d = os.stat("AQIL").st_mtime

# %%
d
# Out:
# 1640190789.6716802

# %%
print(datetime.fromtimestamp(d))
# Out:
# 2021-12-22 20:33:09.671680

# %%
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
#  'execlpe',
#  'execv',
#  'execve',
#  'execvp',
#  'execvpe',
#  'extsep',
#  'fdopen',
#  'fsdecode',
#  'fsencode',
#  'fspath',
#  'fstat',
#  'fsync',
#  'ftruncate',
#  'get_exec_path',
#  'get_handle_inheritable',
#  'get_inheritable',
#  'get_terminal_size',
#  'getcwd',
#  'getcwdb',
#  'getenv',
#  'getlogin',
#  'getpid',
#  'getppid',
#  'isatty',
#  'kill',
#  'linesep',
#  'link',
#  'listdir',
#  'lseek',
#  'lstat',
#  'makedirs',
#  'mkdir',
#  'name',
#  'open',
#  'pardir',
#  'path',
#  'pathsep',
#  'pipe',
#  'popen',
#  'putenv',
#  'read',
#  'readlink',
#  'remove',
#  'removedirs',
#  'rename',
#  'renames',
#  'replace',
#  'rmdir',
#  'scandir',
#  'sep',
#  'set_handle_inheritable',
#  'set_inheritable',
#  'spawnl',
#  'spawnle',
#  'spawnv',
#  'spawnve',
#  'st',
#  'startfile',
#  'stat',
#  'stat_result',
#  'statvfs_result',
#  'strerror',
#  'supports_bytes_environ',
#  'supports_dir_fd',
#  'supports_effective_ids',
#  'supports_fd',
#  'supports_follow_symlinks',
#  'symlink',
#  'sys',
#  'system',
#  'terminal_size',
#  'times',
#  'times_result',
#  'truncate',
#  'umask',
#  'uname_result',
#  'unlink',
#  'urandom',
#  'utime',
#  'waitpid',
#  'walk',
#  'write']

# %%
import os
from datetime import datetime

for qovluq_yolu, qovluq_adlari,fayl_adlari in os.walk("C:\\Users\\uallahverdiyev\\Desktop"):
    for i in qovluq_adlari:
        if (i.startswith("a")):
htm
# index.htm
# index.htm
# index.htm
# index.htm
# index.htm
# index.htm
# index.htm
# Tom-Hanks-takes-photos-set-Da-Vinci-Code-movie-Inferno-s-joined-star-Felicity-Jones-Venice.html
# Tom-Hanks-takes-pictures-Florence-s-stunning-sights-production-continues-Da-Vinci-Code-movie-Inferno.html
# dan-brown-to-attend-sharjah-book-fair-1.1403589.html
# id1159708133.html
# id1114536033.html
# these-are-the-books-to-read-before-they-become-movies-629020739625.html
# ref=sr_1_1.html
# ref=tmm_kin_swatch_0.html
# writers-on-a-new-england-stage-dan-brown.html
# index.htm
# style.css
# db_A&D_book_excerpts.pdf
# db_DF_book_excerpts.pdf
# db_DP_book_excerpts.pdf
# db_dvc_book_excerpts.pdf
# db_INF_book_excerpt.pdf
# db_TLS_book_excerpts.pdf
# presskit.zip
# background.png
# base.css
# bigplay.png
# bigplay.svg
# controls.png
# controls.svg
# fonts.css
# jquery.jscrollpane.css
# loading.gif
# mediaelementplayer.css
# reset.css
# shortcodes.css
# slidebox.css
# superfish.css
# 1140.css
# skin.css
# BodoniSvtyTwoITCTT-Book.eot
# BodoniSvtyTwoITCTT-Book.svg
# BodoniSvtyTwoITCTT-Book.ttf
# BodoniSvtyTwoITCTT-Book.woff
# gillsansmtstd-medium-1.eot
# gillsansmtstd-medium.eot
# gillsansmtstd-medium.svg
# gillsansmtstd-medium.ttf
# gillsansmtstd-medium.woff
# League_Gothic-webfont-1.eot
# League_Gothic-webfont.eot
# League_Gothic-webfont.svg
# League_Gothic-webfont.ttf
# League_Gothic-webfont.woff
# Lobster_1.3-webfont-1.eot
# Lobster_1.3-webfont.eot
# Lobster_1.3-webfont.svg
# Lobster_1.3-webfont.ttf
# Lobster_1.3-webfont.woff
# Museo_Slab_500-webfont-1.eot
# Museo_Slab_500-webfont.eot
# Museo_Slab_500-webfont.svg
# Museo_Slab_500-webfont.ttf
# Museo_Slab_500-webfont.woff
# Novecentowide-Bold-webfont-1.eot
# Novecentowide-Bold-webfont.eot
# Novecentowide-Bold-webfont.svg
# Novecentowide-Bold-webfont.ttf
# Novecentowide-Bold-webfont.woff
# Novecentowide-Light-webfont-1.eot
# Novecentowide-Light-webfont.eot
# Novecentowide-Light-webfont.svg
# Novecentowide-Light-webfont.ttf
# Novecentowide-Light-webfont.woff
# penumbra-serifweb-webfont-1.eot
# penumbra-serifweb-webfont.eot
# penumbra-serifweb-webfont.svg
# penumbra-serifweb-webfont.ttf
# penumbra-serifweb-webfont.woff
# twitter.js
# ajax-loader.gif
# job_38_11.png
# logo_masterclass.png
# responsive-menu-bg.png
# social-icons-big.png
# social-icons-big@2x.png
# social-icons-small.png
# social-icons-small@2x.png
# sprite.png
# text-type-five-bg.png
# toggle-closed.png
# toggle-open.png
# 404.button.png
# aad.quote.png
# authornew.bg.jpg
# book.next.png
# book.prev.png
# books.01.jpg
# books.02.jpg
# books.03.jpg
# books.04.jpg
# books.05.jpg
# books.bg.jpg
# btn.png
# btn.small.png
# buybook.button.png
# dan-brown-new-website-2013.jpeg
# dan-on-twitter-2013.jpeg
# dc.quote.png
# detail.bg.jpg
# detail.dividers.png
# detail.dividers.worldeditions.png
# detail.homebutton.png
# detail.topbar.png
# df.quote.png
# dp.quote.png
# films.01.jpg
# films.02.jpg
# films.bg.jpg
# int1.bg.jpg
# int1.overlay.png
# int2.bg.jpg
# int2.overlay.png
# int3.bg.jpg
# int3.overlay.png
# int4.bg.jpg
# int4.overlay.png
# int5.bg.jpg
# int5.overlay.png
# lightbox.bg.jpg
# lightbox.close.png
# lightbox.next.png
# lightbox.prev.png
# media.bg.jpg
# media.button.png
# nav.bar.png
# nav.fb.png
# nav.goodreads.png
# nav.insta.png
# nav.twitter.png
# new-robert-langdon-thriller-news-image.jpeg
# new.slit.png
# news.bg.jpg
# right-triangle.png
# scrolltotop.button.png
# search.button.png
# secret-fog.png
# secrets.bg.jpg
# secrets.button.png
# secrets.img.png
# share.bg.png
# share.popdown.png
# slits.newwidest.png
# slits.wider.png
# slits.widest.png
# subscibe.button.png
# tls.quote.png
# top.img.png
# top.light.png
# top.media.jpg
# top.media.text.png
# top.news.jpg
# top.news.text.png
# top.privacypolicy.jpg
# top.privacypolicy.text.png
# top.termsofuse.jpg
# top.termsofuse.text.png
# top.worldeditions.jpg
# worldeditions.button.png
# 01.jpg
# 02.jpg
# 03.jpg
# 04.jpg
# 01.jpg
# 02.jpg
# 04.jpg
# 01.jpg
# 02.jpg
# 03.jpg
# 04.jpg
# 01.jpg
# 02.jpg
# 03.jpg
# 04.jpg
# 01.jpg
# 02.jpg
# 03.jpg
# 04.jpg
# ad.jpg
# df.jpg
# dp.jpg
# dvc.jpg
# tls.jpg
# bn1.jpg
# bn2.jpg
# bn3.jpg
# chronicle.jpg
# dvcuncovercode.jpg
# dvcwebquest.jpg
# gma.jpg
# gma2.jpg
# makingofTLSs.jpg
# nbcnews.jpg
# new-england-stage.jpg
# npr.jpg
# npr2.jpg
# nydaily.jpg
# nytimes.jpg
# raitv.jpg
# time.jpg
# todayshow1103.jpg
# wp.jpg
# amazon.png
# bam.png
# barnesandnoble.png
# googleplay.png
# hudson_booksellers.png
# ibooks.png
# indiebound.png
# kindle.png
# kobo.png
# nook.png
# powells.png
# randomhouse.png
# target.png
# walmart.png
# 01.jpg
# 02.jpg
# 04.jpg
# 05.jpg
# 06.jpg
# db.courter.01.jpg
# db.courter.02.jpg
# db.courter.04.jpg
# db.courter.06.jpg
# db.lerner.01.jpg
# common.js
# css3-mediaqueries.js
# front.page.js
# jquery-ui-1.9.2.custom.min.js
# jquery.fitvids.js
# jquery.flexslider-min.js
# jquery.inview.min.js
# jquery.isotope.min.js
# jquery.jscrollpane.min.js
# jquery.mousewheel.js
# jquery.scrollTo.min.js
# jquery.slidebox.js
# jquery.smartresize.js
# jquery.touchSwipe.min.js
# mediaelement-and-player.min.js
# modernizr-2.6.1.min.js
# preloader.js
# retina.js
# smf.lightbox.js
# smf.nav.js
# superfish.js
# dan-brown-international-newspaper-clippings.jpg
# dan-brown-new-website-20131.jpeg
# favicon.ico
# DVC-Catalonia-Grup62B-1.jpg
# DVC-Catalonia-Grup62B.jpg
# dvc.china2_.jpg
# dvc.china_.jpg
# DVCYA_Greece_Psichogios.jpg
# DVCYA_Norway_Bazar.jpg
# DVC_Germany_Bastei.jpg
# DVC_Greece_Psichogios.jpg
# DVC_Hungary_Gabo.jpg
# DVC_Iceland_Bjartur.jpg
# DVC_Israel_Modan.jpg
# DVC_Italy_Mondadori.jpg
# DVC_Japan_Kadokawa1-1.jpg
# DVC_Japan_Kadokawa2.jpg
# DVC_Lebanon_ASP.jpg
# DVC_Norway_Bazar.jpg
# DVC_Poland_SoniaDraga-1.jpg
# DVC_Poland_SoniaDraga.jpg
# DVC_Portugal_Bertrand.jpg
# DVC_Romania_RAO.jpg
# DVC_Russia_AST.jpg
# DVC_Slovakia_Slovart-1.jpg
# DVC_Spain_Booket.jpg
# DVC_Spain_Planeta.jpg
# DVC_Sweden_Bonniers.jpg
# DVC_TheNetherlands_Luitingh.jpg
# DVC_TheNetherlands_Luitingh2.jpg
# DVC_Turkey_Altin.jpg
# DVC_UK_Transworld.jpg
# INFERNO_Macedonia_Kultura-1.jpg
# INFERNO_Slovenia_MladinskaKnjiga-1.jpg
# INFERNO_Ukraine_Family-Leisure.jpg
# INF_Poland_SoniaDraga.jpg
# A_D_Lithuania_Jotema.jpg
# A_D_Slovakia_Slovart-Movie-Tiein.jpg
# A_D_Spain_Booket.jpg
# DP_Spain_Booket1.jpg
# DP_Sweden_Bonniers.jpg
# DP_TheNetherlands_Luitingh.jpg
# DVC_Lithuania_Jotema.jpg
# DVC_Spain_Booket1.jpg
# Inferno-Catalonia-Grup62.jpg
# INFERNO_China_Shanghai-99-Simplified-Chinese.jpg
# INFERNO_China_Shanghai-99-Simplified-Chinese_MovieTieIn.jpg
# INFERNO_Germany_Bastei.jpg
# INFERNO_GREECE_Psichogios2-1.jpg
# INFERNO_GREECE_Psichogios2.jpg
# INFERNO_Hungary_Gabo.jpg
# INFERNO_Iceland_Bjartur.jpg
# INFERNO_Israel_Modan.jpg
# INFERNO_Italy_Mondadori.jpg
# INFERNO_Japan_Kadokawa.jpg
# INFERNO_Japan_Kadokawa2.jpg
# INFERNO_Japan_Kadokawa3.jpg
# INFERNO_Japan_Kadokawa4.jpg
# INFERNO_Japan_Kadokawa5.jpg
# INFERNO_Japan_Kadokawa_Illus.jpg
# INFERNO_Lebanon_ASP.jpg
# INFERNO_Lithuania_Jotema.jpg
# INFERNO_Montenegro_NovaKnjiga.jpg
# INFERNO_Norway_Bazar.jpg
# INFERNO_Romania_RAO.jpg
# INFERNO_Spain_Planeta.jpg
# INFERNO_Sweden_Bonniers.jpg
# INFERNO_TheNetherlands_Luitingh.jpg
# INFERNO_Turkey_Altin.jpg
# INF_Portugal_Bertrand.jpg
# tls.china_.jpg
# TLS_Greece_Psichogios-1.jpg
# TLS_Greece_Psichogios.jpg
# TLS_Hungary_Gabo.jpg
# TLS_Iceland_Bjartur.jpg
# TLS_Italy_Mondadori.jpg
# TLS_Japan_Kadokawa1.jpg
# TLS_Lebanon_ASP.jpg
# TLS_Lithuania_Jotema.jpg
# TLS_Norway_Bazar.jpg
# TLS_Poland_SoniaDraga.jpg
# TLS_Portugal_-Bertrand.jpg
# TLS_Russia_AST.jpg
# TLS_Slovakia_Slovart.jpg
# TLS_Spain_Booket.jpg
# TLS_Spain_Planeta-1.jpg
# TLS_Sweden_Bonniers.jpg
# TLS_TheNetherlands_Luitingh-1.jpg
# TLS_Turkey_Altin.jpg
# TLS_UK_Transworld-1.jpg
# Website_Banner3_v2-1024x327.jpg
# Website_Banner3_v2-1536x491.jpg
# Website_Banner3_v2-2048x654.jpg
# Website_Banner3_v2-300x96.jpg
# Website_Banner3_v2-768x245.jpg
# Wild-Symphony-jacket_v6.jpg
# WS_Web_Image.jpg
# WS_Web_Image2.jpg
# DBWeb2.jpg
# ws_web3.jpg
# ws_web5.jpg
# Langdon2.jpg
# TLS_2.jpg
# TLS_3.jpg
# Website_Premiere.jpg
# The-Da-Vinci-Code_Stage_Web.jpg
# TLS_SeriesPoster_Resize-1.jpg
# ST2009091402737.html
# wlwmanifest.xml
# style.min.css
# wp-embed.min.js
# jquery-migrate.min.js
# jquery.min.js
# index.htm.json
# embed-1.json
# embed-1.xml
# embed-10.json
# embed-10.xml
# embed-11.json
# embed-11.xml
# embed-12.json
# embed-12.xml
# embed-2.json
# embed-2.xml
# embed-3.json
# embed-3.xml
# embed-4.json
# embed-4.xml
# embed-5.json
# embed-5.xml
# embed-6.json
# embed-6.xml
# embed-7.json
# embed-7.xml
# embed-8.json
# embed-8.xml
# embed-9.json
# embed-9.xml
# embed.json
# embed.xml
# 1015.json
# 1845.json
# 1882.json
# 402.json
# 433.json
# 451.json
# 460.json
# 478.json
# 479.json
# 480.json
# 628.json
# 681.json
# 686.json
# 09ccb32e-90da-4f51-9849-004c825449f1.jfif
# 2104020120132300-autogenerateddocument.pdf.pdf
# a7453a68-64db-4e2b-8177-530571c6a086.png
# ATM proqrami.py
# Azer DV2023.pdf
# bdgt.xlsx
# class.py
# db.py
# decorators.ipynb
# dfh.txt
# fayl ilə əməliyyatlar.ipynb
# ffff.py
# General-20211025_195745-Meeting Recording.mp4
# Hell yollar.py
# IS-de verilenler tipi ve obyektler.ipynb
# iterator ve generatorlar.ipynb
# kitabxana.db
# kitabxana1.db
# kitabxana2.db
# kitabxana3.db
# listler, tuple, dictionary.ipynb
# loops.ipynb
# Mentiqi deyerler ve qarsilasdirma operatorlari, mentiqi baglayicilar ve if elif else bloku.ipynb
# metn.txt
# Microsoft Edge.lnk
# Microsoft Teams.lnk
# PR Soft.lnk
# praktika.py
# Python Programlaşdırma Bootcamp-20211101_200816-Meeting Recording.mp4
# Python Programming Bootcamp-20211108_173342-Meeting Recording.mp4
# Python Programming Bootcamp.pdf
# Python Programming Language-20211213_200616-Meeting Recording.mp4
# Python Proqramlaşdırma Bootcamp-20211106_105635-Meeting Recording.mp4
# quvvet3.py
# sanan.txt
# Sqlite Verilenlər Bazası.ipynb
# T-13.ipynb
# test_video_for_rendering.mp4
# The role of road transport in the development of tourism.docx
# Untitled.ipynb
# Verilənlərin Tipinin dəyişdirilməsi - input() - format - print() funksiyası.ipynb
# vurma cedveli.py
# fayl ilə əməliyyatlar-checkpoint.ipynb
# listler, tuple, dictionary-checkpoint.ipynb
# loops-checkpoint.ipynb
# Mentiqi deyerler ve qarsilasdirma operatorlari, mentiqi baglayicilar ve if elif else bloku-checkpoint.ipynb
# Sqlite Verilenlər Bazası-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Verilənlərin Tipinin dəyişdirilməsi - input() - format - print() funksiyası-checkpoint.ipynb
# Kitabxana.py
# kitabxana3.db
# kütüphane.db
# proyekt_test.py
# test_decorator.py
# Kitabxana.cpython-310.pyc
# kütüphane.cpython-310.pyc
# README.md
# Fayl açmaq və fayla yazma əməliyyatları.ipynb
# Fayl oxumə əməliyyatları.ipynb
# Fayllarda dəyişiklik etmə əməliyyatları.ipynb
# Fayllarda istifadə olunan funksiyalar.ipynb
# Fayl açmaq və fayla yazma əməliyyatları-checkpoint.ipynb
# Fayl oxumə əməliyyatları-checkpoint.ipynb
# Fayllarda dəyişiklik etmə əməliyyatları-checkpoint.ipynb
# Fayllarda istifadə olunan funksiyalar-checkpoint.ipynb
# bjk.txt
# fb.txt
# futbolcular.txt
# gs.txt
# Programlama Ödevi Çözümleri -  Dosya İşlemleri.ipynb
# Proqramlaşdırma tapşırıq - Fayl ilə əməliyyatlar.ipynb
# Programlama Ödevi Çözümleri -  Dosya İşlemleri-checkpoint.ipynb
# Proqramlaşdırma tapşırıq - Fayl ilə əməliyyatlar-checkpoint.ipynb
# dosya.txt
# not_hesaplama.py
# break ve continue .ipynb
# Döngü Yapılarını Kullanma.ipynb
# For Döngüleri.ipynb
# List Comprehension.ipynb
# range() Fonksiyonu.ipynb
# While Döngüleri.ipynb
# break ve continue -checkpoint.ipynb
# Döngü Yapılarını Kullanma-checkpoint.ipynb
# For Döngüleri-checkpoint.ipynb
# List Comprehension-checkpoint.ipynb
# range() Fonksiyonu-checkpoint.ipynb
# While Döngüleri-checkpoint.ipynb
# Programlasdirma TAPSIRIQ helleri -  Loops.ipynb
# TAPŞIRIQ-döngülər.ipynb
# Programlasdirma TAPSIRIQ helleri -  Loops-checkpoint.ipynb
# TAPŞIRIQ-döngülər-checkpoint.ipynb
# atm_ornegi.py
# factorial.py
# fibonacci_serisi.py
# kullanıcı_girişi_while_döngüsü.py
# Fonksiyonlar.ipynb
# Fonksiyonlarda Parametre Türleri.ipynb
# Fonksiyonlarda Return.ipynb
# Global ve Yerel değişkenler.ipynb
# Lambda İfadeleri.ipynb
# Metodlar.ipynb
# Fonksiyonlar-checkpoint.ipynb
# Fonksiyonlarda Parametre Türleri-checkpoint.ipynb
# Fonksiyonlarda Return-checkpoint.ipynb
# Global ve Yerel değişkenler-checkpoint.ipynb
# Lambda İfadeleri-checkpoint.ipynb
# Metodlar-checkpoint.ipynb
# Programlama Tapşırıq - Funksiyalar.ipynb
# Proqramlaşdırma Həll yolları - Funksiyalar.ipynb
# Programlama Ödevi - Fonksiyonlar-checkpoint.ipynb
# Proqramlaşdırma Həll yolları - Funksiyalar-checkpoint.ipynb
# asal_mi.py
# tam_bolenler.py
# Fonksiyonlar.ipynb
# Fonksiyonlarda Parametre Türleri.ipynb
# Fonksiyonlarda Return.ipynb
# Global ve Yerel değişkenler.ipynb
# lambda ifadeleri.ipynb
# Metodlar.ipynb
# Səhvlər və İstisnalar .ipynb
# xətanın tutulması - try,except,finally.ipynb
# Səhvlər və İstisnalar -checkpoint.ipynb
# xətanın tutulması - try,except,finally-checkpoint.ipynb
# Programlama Ödevi Çözümleri -  Hatalar ve İstisnalar.ipynb
# Proqramlaşdırma tapşırıq - Xətalar və istisnalar.ipynb
# Programlama Ödevi Çözümleri -  Hatalar ve İstisnalar-checkpoint.ipynb
# Proqramlaşdırma tapşırıq - Xətalar və istisnalar-checkpoint.ipynb
# Hata Yakalama - try,except,finally.ipynb
# Hata Yakalama - try,except,finally-checkpoint.ipynb
# Koşullu Durumlar - if - elif - else koşullu durumları .ipynb
# Koşullu Durumlar - if-else koşullu durumları.ipynb
# Mantıksal Bağlaçlar.ipynb
# Mantıksal Değerler ve Karşılaştırma Operatörleri.ipynb
# Koşullu Durumlar - if - elif - else koşullu durumları -checkpoint.ipynb
# Koşullu Durumlar - if-else koşullu durumları-checkpoint.ipynb
# Mantıksal Bağlaçlar-checkpoint.ipynb
# Mantıksal Değerler ve Karşılaştırma Operatörleri-checkpoint.ipynb
# basit_hesap_makinesi.py
# kullanıcı_girişi.py
# Ppraktka_helleri_sertler.ipynb
# praktika-statements1.ipynb
# PRATİKA - Şərtlər.ipynb
# Ppraktka_helleri_sertler-checkpoint.ipynb
# praktika-statements-checkpoint.ipynb
# PRATİKA - Şərtlər-checkpoint.ipynb
# Koşullu Durumlar - if - elif - else koşullu durumları .ipynb
# Koşullu Durumlar - if-else koşullu durumları.ipynb
# Mantıksal Bağlaçlar.ipynb
# Mantıksal Değerler ve Karşılaştırma Operatörleri.ipynb
# Kendi Modüllerimizi Yazmak.ipynb
# Modül Kullanımı - math Modülü.ipynb
# Modül Mantığı.ipynb
# Proqramlaşdırma tapşırıqları  - Modullar.ipynb
# Kendi Modüllerimizi Yazmak-checkpoint.ipynb
# Modül Kullanımı - math Modülü-checkpoint.ipynb
# Modül Mantığı-checkpoint.ipynb
# Proqramlaşdırma tapşırıqları  - Modullar-checkpoint.ipynb
# sayı_tahmin_oyunu.py
# Modül Kullanımı - math Modülü.ipynb
# OOP - (Inheritance).ipynb
# OOP - Classes.ipynb
# OOP - Methods.ipynb
# OOP - Special methods.ipynb
# OOP Logic.ipynb
# Programlama Ödevi -  Nesne Tabanlı Programlama.ipynb
# OOP - (Inheritance)-checkpoint.ipynb
# OOP - Classes-checkpoint.ipynb
# OOP - Methods-checkpoint.ipynb
# OOP - Special methods-checkpoint.ipynb
# OOP Logic-checkpoint.ipynb
# pult_sinifi.py
# Nesne Tabanlı Programlama -  Özel Metodlar.ipynb
# Nesne Tabanlı Programlama - Kalıtım (Inheritance).ipynb
# Nesne Tabanlı Programlama - Metodlar.ipynb
# Nesne Tabanlı Programlama - Sınıflar.ipynb
# Programlama Ödevi -  PyQt5 Arayüz Geliştirme.ipynb
# PyQt5 Kurulumu.ipynb
# buton olusturma.py
# butonlar ve fonksiyonları.py
# checkbox olusturma.py
# etiket olusturma.py
# horizontal ve vertical layout.py
# input alanı ve lineedit.py
# kullanıcı_girişi.py
# menuler.py
# notepad.py
# pencere_olusturma.py
# python.png
# radiobutton olusturma.py
# yazı alanları ve textedit.py
# Decorator Fonksiyonların Oluşturulması ve Kullanılması.ipynb
# Fonksiyonları Dönmek ve Parametre Olarak Göndermek.ipynb
# İç içe Fonksiyonlar ve Fonksiyon Parametreleri.ipynb
# Decorator Fonksiyonların Oluşturulması ve Kullanılması-checkpoint.ipynb
# Fonksiyonları Dönmek ve Parametre Olarak Göndermek-checkpoint.ipynb
# İç içe Fonksiyonlar ve Fonksiyon Parametreleri-checkpoint.ipynb
# Programlama Ödevi -  Decoratorlar.ipynb
# Programlama Ödevi Çözümleri  - Decoratorlar.ipynb
# Programlama Ödevi -  Decoratorlar-checkpoint.ipynb
# Programlama Ödevi Çözümleri  - Decoratorlar-checkpoint.ipynb
# decorator.py
# Decorator Fonksiyonların Oluşturulması ve Kullanılması.ipynb
# Fonksiyonları Dönmek ve Parametre Olarak Göndermek.ipynb
# İç içe Fonksiyonlar ve Fonksiyon Parametreleri.ipynb
# All ve Any Fonksiyonları .ipynb
# Enumerate Fonksiyonu.ipynb
# Filter Fonksiyonu.ipynb
# Map Fonksiyonu.ipynb
# Reduce Fonksiyonu.ipynb
# reduce.jpg
# Zip Fonksiyonu.ipynb
# All ve Any Fonksiyonları -checkpoint.ipynb
# Enumerate Fonksiyonu-checkpoint.ipynb
# Filter Fonksiyonu-checkpoint.ipynb
# Map Fonksiyonu-checkpoint.ipynb
# Reduce Fonksiyonu-checkpoint.ipynb
# Zip Fonksiyonu-checkpoint.ipynb
# Built-in Funksiyalar.ipynb
# Programlama Ödevi Çözümleri -  Gömülü Fonksiyonlar.ipynb
# Built-in Funksiyalar-checkpoint.ipynb
# Programlama Ödevi Çözümleri -  Gömülü Fonksiyonlar-checkpoint.ipynb
# All ve Any Fonksiyonları .ipynb
# Enumerate Fonksiyonu.ipynb
# Filter Fonksiyonu.ipynb
# Map Fonksiyonu.ipynb
# Reduce Fonksiyonu.ipynb
# Zip Fonksiyonu.ipynb
# Generatorların Oluşturulması ve Kullanılması.ipynb
# Iteratorlerin Oluşturulması ve Kullanılması.ipynb
# Generatorların Oluşturulması ve Kullanılması-checkpoint.ipynb
# Iteratorlerin Oluşturulması ve Kullanılması-checkpoint.ipynb
# Programlama Ödevi -  Iteratorlar ve Generatorlar.ipynb
# Programlama Ödevi Çözümleri -  Iteratorlar ve Generatorlar.ipynb
# Programlama Ödevi -  Iteratorlar ve Generatorlar-checkpoint.ipynb
# generator.py
# iterator.py
# Generatorların Oluşturulması ve Kullanılması.ipynb
# Iteratorlerin Oluşturulması ve Kullanılması.ipynb
# kütüphane.db
# Programlama Ödevi -  Sqlite Veritabanı .ipynb
# Sqlite Veritabanı ve Tablo Oluşturma.ipynb
# Tablo.png
# Tablodaki Verileri Güncelleme ve Silme.ipynb
# Tablodaki Verileri Çekme.ipynb
# Tablolara Veri Ekleme.ipynb
# Untitled.ipynb
# veritabanı.py
# Programlama Ödevi -  Sqlite Veritabanı -checkpoint.ipynb
# Sqlite Veritabanı ve Tablo Oluşturma-checkpoint.ipynb
# Tablodaki Verileri Güncelleme ve Silme-checkpoint.ipynb
# Tablodaki Verileri Çekme-checkpoint.ipynb
# Tablolara Veri Ekleme-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# kütüphane.py
# proje_deneme.py
# Dictionary.ipynb
# Istifadeciden giris alma - input() funksiyasi.ipynb
# Karakter Dizileri - Stringler.ipynb
# listler.ipynb
# Matematik Operatörleri.ipynb
# Print Funksiyasi ve Formatlama.ipynb
# Pythonda Sayılar.ipynb
# Tuplelar.ipynb
# Verilenler tipinin deyisdirilmesi.ipynb
# Dictionary-checkpoint.ipynb
# Istifadeciden giris alma - input() funksiyasi-checkpoint.ipynb
# listler-checkpoint.ipynb
# Print Funksiyasi ve Formatlama-checkpoint.ipynb
# Tuplelar-checkpoint.ipynb
# Verilenler tipinin deyisdirilmesi-checkpoint.ipynb
# kok_bulma.py
# oyuncu_kaydetme.py
# Programlama Ödevi - Temel Python Objeleri ve Veri Yapıları.ipynb
# Programlama Ödevi Çözümleri - Temel Python Objeleri ve Veri Yapıları.ipynb
# Programlama Ödevi Çözümleri - Temel Python Objeleri ve Veri Yapıları-checkpoint.ipynb
# Demetler (Tuplelar).ipynb
# Karakter Dizileri - Stringler.ipynb
# Kullanıcıdan Girdi Alma - input() Fonksiyonu.ipynb
# Listeler.ipynb
# Matematik Operatörleri.ipynb
# Print Fonksiyonu ve Formatlama.ipynb
# Pythonda Sayılar.ipynb
# Sözlükler - Dictionary.ipynb
# Veri tipi Dönüşümleri.ipynb
# Listeler-checkpoint.ipynb
# DateTime Modülü.ipynb
# Pillow Modülü ile Fotoğraf İşlemleri.ipynb
# Programlama Ödevi - İleri Seviye Modüller.ipynb
# Requests ve BeautifulSoup Modülü.ipynb
# Requests ve Json ile Döviz Uygulaması.ipynb
# Smtp Modülü ile Mail Gönderme.ipynb
# Sys Modülü.ipynb
# DateTime Modülü-checkpoint.ipynb
# Pillow Modülü ile Fotoğraf İşlemleri-checkpoint.ipynb
# Programlama Ödevi - İleri Seviye Modüller-checkpoint.ipynb
# Requests ve BeautifulSoup Modülü-checkpoint.ipynb
# Requests ve Json ile Döviz Uygulaması-checkpoint.ipynb
# Smtp Modülü ile Mail Gönderme-checkpoint.ipynb
# Sys Modülü-checkpoint.ipynb
# DateTime.py
# osmodülü.py
# test2.txt
# atatürk.jpg
# kuş.jpg
# kuş2.jpg
# kuş3.jpg
# kuş4.jpg
# kuş5.jpg
# kuş6.jpg
# kuş7.jpg
# kuş8.jpg
# kuş9.jpg
# photothumb.db
# pillow modülü.py
# Thumbs.db
# dovizuygulaması.py
# imdb.py
# requestsvebeautifulsoup.py
# Mail_Gonderme.py
# sys_modülü.py
# İleri Seviye Karakter Dizileri (Stringler).ipynb
# İleri Seviye Kümeler (Sets).ipynb
# İleri Seviye Listeler.ipynb
# İleri Seviye Sayılar.ipynb
# İleri Seviye Karakter Dizileri (Stringler)-checkpoint.ipynb
# İleri Seviye Kümeler (Sets)-checkpoint.ipynb
# İleri Seviye Listeler-checkpoint.ipynb
# İleri Seviye Sayılar-checkpoint.ipynb
# dosya_islemleri.py
# metin.txt
# İleri Seviye Karakter Dizileri (Stringler).ipynb
# İleri Seviye Kümeler (Sets).ipynb
# İleri Seviye Listeler.ipynb
# İleri Seviye Sayılar.ipynb
# həllər-is.ipynb
# mailler.txt
# Tapşırıq1-is-advanced.ipynb
# şiir.txt
# həllər-is-checkpoint.ipynb
# Tapşırıq1-is-advanced-checkpoint.ipynb
# install.bat
# jpcsc.dll
# smartcardreader.exe
# uninstall.bat
# First Video High Quality.mp4
# Fourth Video High Quality.mp4
# Second Video High Quality.mp4
# Third Video High Quality.mp4
# Meeting in _General_-20211117_201020-Meeting Recording.mp4
# opera error.png
# PR Soft.lnk
# Python Programming Bootcamp-20211120_110441-Meeting Recording.mp4
# Python Programming Bootcamp-20211127_110942-Meeting Recording.mp4
# topics - 27112021.txt
# try-except-final.ipynb
# try-except-finally-practise.ipynb
# my_database.txt
# 26.11.2021 Tapsiriq.ipynb
# pult6.py
# pult.py
# mute mode.py
# Untitled13.py
# Pult.py
# Aqil.py
# airlines.py
# Flight_Gunel.py
# Airport_sis.py
# LIMITER.AUD
# MASTEREQ.AUD
# MIDI.MPR
# QTPRESET.QTP
# SETUP.GBL
# RAM.KMP
# USER01.PAD
# USER02.PAD
# USER03.PAD
# USER04.PAD
# USER05.PAD
# USER06.PAD
# USER07.PAD
# USER08.PAD
# USER09.PAD
# USER10.PAD
# RAM01.PCM
# RAM02.PCM
# RAM03.PCM
# RAM04.PCM
# RAM05.PCM
# RAM06.PCM
# RAM07.PCM
# RAM08.PCM
# RAM09.PCM
# RAM10.PCM
# RAM11.PCM
# RAM12.PCM
# RAM13.PCM
# RAM14.PCM
# RAM15.PCM
# RAM16.PCM
# RAM17.PCM
# RAM18.PCM
# RAM19.PCM
# RAM20.PCM
# RAM21.PCM
# RAM22.PCM
# RAM23.PCM
# RAM24.PCM
# RAM25.PCM
# RAM26.PCM
# RAM27.PCM
# RAM28.PCM
# RAM29.PCM
# RAM30.PCM
# RAM31.PCM
# RAM32.PCM
# RAM33.PCM
# RAM34.PCM
# RAM35.PCM
# RAM36.PCM
# RAM37.PCM
# RAM38.PCM
# RAM39.PCM
# RAM40.PCM
# RAM41.PCM
# RAM42.PCM
# RAM43.PCM
# RAM44.PCM
# RAM45.PCM
# RAM46.PCM
# RAM47.PCM
# RAM48.PCM
# RAM49.PCM
# RAM50.PCM
# RAM51.PCM
# RAM52.PCM
# RAM53.PCM
# RAM54.PCM
# RAM55.PCM
# RAM56.PCM
# RAM57.PCM
# RAM58.PCM
# RAM59.PCM
# RAM60.PCM
# RAM61.PCM
# RAM62.PCM
# RAM63.PCM
# RAM64.PCM
# RAM65.PCM
# RAM66.PCM
# RAM67.PCM
# RAM68.PCM
# RAM69.PCM
# RAM70.PCM
# RAM71.PCM
# RAM72.PCM
# RAM73.PCM
# RAM74.PCM
# RAM75.PCM
# RAM76.PCM
# RAM77.PCM
# RAM78.PCM
# RAM79.PCM
# RAM80.PCM
# RAM81.PCM
# RAM82.PCM
# RAM83.PCM
# RAM84.PCM
# RAM85.PCM
# RAM86.PCM
# RAM87.PCM
# RAM88.PCM
# RAM89.PCM
# RAM90.PCM
# RAM91.PCM
# RAM92.PCM
# RAM93.PCM
# RAM94.PCM
# RAM95.PCM
# RAM96.PCM
# RAM97.PCM
# RAM98.PCM
# RAM99.PCM
# BANK01.PRF
# BANK02.PRF
# BANK03.PRF
# BANK04.PRF
# BANK05.PRF
# BANK06.PRF
# BANK07.PRF
# BANK08.PRF
# LISTDB.SBL
# BANK01.SBD
# BANK02.SBD
# BANK03.SBD
# BANK04.SBD
# BANK05.SBD
# BANK06.SBD
# USER01.PCG
# USER02.PCG
# USERDK.PCG
# FAVORITE01.STY
# FAVORITE02.STY
# FAVORITE03.STY
# FAVORITE04.STY
# FAVORITE05.STY
# FAVORITE06.STY
# USER01.STY
# USER02.STY
# USER03.STY
# Kitabxana.py
# kitabxana3.db
# proyekt_test.py
# Kitabxana.cpython-310.pyc
# Metodlar.ipynb
# pult.py
# pult_sinifi.ipynb
# Python - OOP.ipynb
# test.py
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# pult_sinifi-checkpoint.ipynb
# Python - OOP-checkpoint.ipynb
# test123.ipynb
# test123-checkpoint.ipynb
# Aqil - Fayl ilə əməliyyatlar.ipynb
# Aqil_Proqramlaşdırma_tapşırıq_Xətalar_və_istisnalar.ipynb
# Aqil - Fayl ilə əməliyyatlar-checkpoint.ipynb
# Aqil_Proqramlaşdırma_tapşırıq_Xətalar_və_istisnalar-checkpoint.ipynb
# Musiqi Albomu.py
# test.py
# Tapsiriq Aqil 07.12.2021.py
# problem1.py
# problem3.py
# problem4.py
# functions.py
# Built-in functions.ipynb
# Built-in functions-checkpoint.ipynb
# T-12.ipynb
# tapsiriq.ipynb
# Fayl ilə əməliyyatlar.ipynb
# Xətalar və istisnalar.ipynb
# Fayl ilə əməliyyatlar-checkpoint.ipynb
# Xətalar və istisnalar-checkpoint.ipynb
# T-10.ipynb
# T-11.ipynb
# Musiqi proyekti.py
# studio.db
# Studio.py
# Studio.cpython-310.pyc
# Kitabxana.cpython-310.pyc

# %%
print("salam")
# Out:
# salam

# %%
import sys
a = input("a:")
b = input("b:")

sys.exit()

c = input("c:")
# Out:
# a:a
# b:s
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\uallahverdiyev\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
stderr ve stdout

# %%
print("salam",sep="",end="",file=sys.stdout)
# Out:
# salam

# %%
# sys.stdout - Bu standart fayl, proessin ekrana cixmasini temin edir
# stdin - Bu standart processin istifadecin input almasini temin edir
# stderr Bu standart fayl, prosesin xeta mesajlarini ekrana cap etmesini temin edir

# %%
import sys

# %%
sys.stderr.write("Bura bir xeta mesaji\n")
# Out:
# Bura bir xeta mesaji

# %%
2 + "a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-03b0bc6ba911> in <module>
# ----> 1 2 + "a"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
sys.stderr.flush()

# %%
sys.stdout.write("Normal print olunan yazimiz !!!\n")
# Out:
# Normal print olunan yazimiz !!!

# %%
# Requests and BeautifulSoup modulu
